# %%
import json 
import csv
import pandas as pd
import os

# Go up one dir

if not os.path.exists("ads/"):
    os.chdir("..")

# %%
import warnings
warnings.filterwarnings("ignore")

run_ids = ["20230518_1957", "20230526_1750", "20230527_2230",
               "20230530_1949", "20230529_2213", "20230601_1751",
               "20230606_0332", "20230606_1947", "20230615_2208"]
        
def get_tagging(info, database):
    # info is a tuple (video_url, site)
    
    url, site = info
    
    url_db = database[database["preroll_ad_video_url"]==url]
    if len(url_db) != 0:
        return url_db.iloc[0]["tag"], url_db.iloc[0]["is_scam"]
    
    site_db = database[database["preroll_ad_site"]==site]
    if len(site_db) != 0:
        return site_db.iloc[0]["tag"], site_db.iloc[0]["is_scam"]
    
    return None, None


# build the database
def build_database():
    tag_header = ["preroll_ad_video_url", "preroll_ad_site", "preroll_ad_advertiser",
                  "preroll_ad_location", "id", "tag", "is_scam"]

    db = pd.read_excel("ads/preroll_ads_tagging.xlsx", sheet_name = run_ids)
    dfs = []

    for run_id in run_ids:
        df = db.get(run_id)
        df = df[df['preroll_ad_video_url'].notna()]
        df['run_id'] = run_id
        dfs.append(df)

    database = pd.concat(dfs, ignore_index=True)
    return database

# %%
database = build_database()
database
# Out:
#                              preroll_ad_video_url
# 0     https://www.youtube.com/watch?v=LCTqyxEUmHU  \
# 1     https://www.youtube.com/watch?v=DcD1tOMiIvk
# 2     https://www.youtube.com/watch?v=jR-gYFNLVxs
# 3     https://www.youtube.com/watch?v=PahO1czqaqM
# 4     https://www.youtube.com/watch?v=kuQIm72_H3o
# ...                                           ...
# 1322  https://www.youtube.com/watch?v=Niyh4CkH7RY
# 1323  https://www.youtube.com/watch?v=znjwdCCguBw
# 1324  https://www.youtube.com/watch?v=vVmVBwkqMoU
# 1325  https://www.youtube.com/watch?v=QL_3IL1wnqE
# 1326  https://www.youtube.com/watch?v=cPLIqk9o7I4
#
#                            preroll_ad_site      preroll_ad_advertiser
# 0                      parasitesnomore.com    PureHealth Research LLC  \
# 1       pacificrimathletics.com/online-reg      Pacific Rim Athletics
# 2                         click.doodly.com                 Voomly LLC
# 3                 go.masterclass-piano.com      Creators Secrets Inc.
# 4                       cf.spybriefing.com                        NaN
# ...                                    ...                        ...
# 1322                          waldenu.edu                         NaN
# 1323                     hiddenvalley.com                         NaN
# 1324                         onetrust.com               OneTrust, LLC
# 1325                        modelousa.com   Constellation Brands, Inc
# 1326  instacart.com/store/brands/bud-l...                         NaN
#
#      preroll_ad_location                    tag  is_scam
# 0          United States        Health Products      1.0  \
# 1          United States                Fitness      1.0
# 2          United States      Software Services      0.0
# 3          United States   Educational Services      1.0
# 4                    NaN                Fitness      1.0
# ...                  ...                    ...      ...
# 1322                 NaN  For-profit University      NaN
# 1323                 NaN            Food/Drinks      NaN
# 1324       United States      Software Services      NaN
# 1325       United States            Food/Drinks      NaN
# 1326                 NaN            Food/Drinks      NaN
#
#                                           Notes         run_id  df_index
# 0                                           NaN  20230518_1957       NaN  \
# 1     athletic training, 10k for a short course  20230518_1957       NaN
# 2                   sketchy hidden subscription  20230518_1957       NaN
# 3                                           NaN  20230518_1957       NaN
# 4           self-defense training, very sketchy  20230518_1957       NaN
# ...                                         ...            ...       ...
# 1322                                        NaN  20230615_2208       NaN
# 1323                                        NaN  20230615_2208       NaN
# 1324                                        NaN  20230615_2208       NaN
# 1325                                        NaN  20230615_2208       NaN
# 1326                                        NaN  20230615_2208       NaN
#
#           id
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 1322  4927.0
# 1323  4944.0
# 1324  4964.0
# 1325  4976.0
# 1326  4989.0
#
# [1327 rows x 10 columns]

# %%
from collections import Counter


info = ["video_url",
          "preroll_ad_video_url", "preroll_ad_site","preroll_ad_info",
          "preroll_ad2_video_url", "preroll_ad2_site","preroll_ad2_info",]

header = ["id"] + info + ["tag", "is_scam", "tag2", "is_scam2"]
df_data = []
preroll_tags, preroll2_tags, preroll_scam, preroll2_scam = [], [], [], []

for id in run_ids:

    ad_json_file = open(f"ads/ads_{id}.json", "r", encoding="utf-8")

    for line in ad_json_file:
        json_data = json.loads(line)

        if json_data['preroll_ad_video_url'] and json_data['preroll_ad2_video_url']:
            if json_data['preroll_ad_video_url'] != json_data['video_url'] and json_data['preroll_ad2_video_url'] != json_data['video_url']:
                
                video_url, site = json_data["preroll_ad_video_url"], json_data["preroll_ad_site"]
                video_url2, site2 = json_data["preroll_ad2_video_url"], json_data["preroll_ad2_site"]
                tag, is_scam = get_tagging((video_url, site), database)
                tag2, is_scam2 = get_tagging((video_url2, site2), database)
                
                preroll_tags.append(tag)
                preroll2_tags.append(tag2)
                if is_scam:
                    preroll_scam.append(tag)
                if is_scam2:
                    preroll2_scam.append(tag2)
                
                data = [id] + [json_data[cate] for cate in info] + [tag, is_scam, tag2, is_scam2]
                df_data.append(data)
    
df = pd.DataFrame(df_data, columns=header)
df
# Out:
#                 id                                    video_url
# 0    20230518_1957  https://www.youtube.com/watch?v=6v4SLn-_GeE  \
# 1    20230518_1957  https://www.youtube.com/watch?v=HC05gzknxAI
# 2    20230518_1957  https://www.youtube.com/watch?v=EY5uZrnAJ2Y
# 3    20230518_1957  https://www.youtube.com/watch?v=4r-4mqy4F7Y
# 4    20230518_1957  https://www.youtube.com/watch?v=e54vOGWJIqs
# ..             ...                                          ...
# 312  20230615_2208  https://www.youtube.com/watch?v=iOJwhtqyfMg
# 313  20230615_2208  https://www.youtube.com/watch?v=CCDUJ54sCIM
# 314  20230615_2208  https://www.youtube.com/watch?v=LBXYLKCveBk
# 315  20230615_2208  https://www.youtube.com/watch?v=oKTNyB2aCOU
# 316  20230615_2208  https://www.youtube.com/watch?v=3qAV7DaNk1s
#
#                             preroll_ad_video_url
# 0    https://www.youtube.com/watch?v=BuIz-f6uUcM  \
# 1    https://www.youtube.com/watch?v=3l7BbB4KDAs
# 2    https://www.youtube.com/watch?v=1B9v3GbE2G4
# 3    https://www.youtube.com/watch?v=kEMXZu2scKE
# 4    https://www.youtube.com/watch?v=aEIZBfWF_jA
# ..                                           ...
# 312  https://www.youtube.com/watch?v=NmDtVQidvms
# 313  https://www.youtube.com/watch?v=Kz8np8t7PIw
# 314  https://www.youtube.com/watch?v=ke3N8IMESW4
# 315  https://www.youtube.com/watch?v=h3vdA3jIvHU
# 316  https://www.youtube.com/watch?v=lds68dgIZq0
#
#                           preroll_ad_site
# 0             subscribe.theepochtimes.com  \
# 1                          betterhelp.com
# 2                                temu.com
# 3                           grammarly.com
# 4                           grammarly.com
# ..                                    ...
# 312                    brooksrunning.com
# 313  usa.philips.com/dental-professio...
# 314                               dc.com
# 315                            tums.com/
# 316                            starz.com
#
#                                        preroll_ad_info
# 0    [MARKETFUEL SUBSCRIPTION SERVICES, United States]  \
# 1                    [BetterHelp, Inc., United States]
# 2                                         [None, None]
# 3                     [Grammarly, Inc., United States]
# 4                     [Grammarly, Inc., United States]
# ..                                                 ...
# 312                                       [None, None]
# 313         [Philips North America LLC, United States]
# 314  [Warner Brothers Entertainment Inc., United St...
# 315                                       [None, None]
# 316         [Starz Entertainment, LLC., United States]
#
#                            preroll_ad2_video_url
# 0    https://www.youtube.com/watch?v=T8fGIon1JZM  \
# 1    https://www.youtube.com/watch?v=c0ljp5YB1OE
# 2    https://www.youtube.com/watch?v=akLmxtIAoC4
# 3    https://www.youtube.com/watch?v=0PoMVDor5tY
# 4    https://www.youtube.com/watch?v=MopERx1yXvQ
# ..                                           ...
# 312  https://www.youtube.com/watch?v=7X9F_bTD3rc
# 313  https://www.youtube.com/watch?v=LsDsmVSI0hI
# 314  https://www.youtube.com/watch?v=-67OAjLlCe8
# 315  https://www.youtube.com/watch?v=FNwDZc0MNGU
# 316  https://www.youtube.com/watch?v=F52VPBFZw8Q
#
#                          preroll_ad2_site
# 0                 smartinvestorsdaily.com  \
# 1                       wellness-hub.life
# 2                         livingproof.com
# 3                       wellness-hub.life
# 4           go.overwolf.com/free-download
# ..                                    ...
# 312  benefiber.com/fiber-supplement-p...
# 313                          youtube.com
# 314                            macys.com
# 315                               dc.com
# 316                 justthrivehealth.com
#
#                                       preroll_ad2_info                tag
# 0              [Powderday Digital, LLC, United States]               News  \
# 1                                         [None, None]    Health Services
# 2                   [Living Proof inc., United States]        Electronics
# 3                          [Kuyami Inc, United States]  Software Services
# 4                               [Overwolf LTD, Israel]  Software Services
# ..                                                 ...                ...
# 312                                       [None, None]           Clothing
# 313          [UNIVERSITY OF CINCINNATI, United States]    Health Services
# 314                                       [None, None]      Entertainment
# 315  [Warner Brothers Entertainment Inc., United St...    Health Products
# 316  [DMS Natural Health, LLC d/b/a Just Thrive Pro...      Entertainment
#
#      is_scam                  tag2  is_scam2
# 0        0.0             Financial       1.0
# 1        0.0       Health Products       1.0
# 2        0.0                Beauty       0.0
# 3        0.0       Health Products       1.0
# 4        0.0                 Games       0.0
# ..       ...                   ...       ...
# 312      NaN       Health Products       0.0
# 313      0.0  Nonprofit University       NaN
# 314      NaN                Beauty       0.0
# 315      0.0         Entertainment       NaN
# 316      NaN       Health Products       NaN
#
# [317 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

counter = Counter(preroll_tags).most_common()
counter2 = Counter(preroll2_tags)
scam_counter = Counter(preroll_scam)
scam_counter2 = Counter(preroll2_scam)

cate = [k for k, v in counter]
preroll_ad_count = [v for k,v in counter]
preroll_ad2_count = [counter2[i] for i in cate]
preroll_ad_scam = [scam_counter[k] if k in scam_counter.keys() else 0 for k in cate]
preroll_ad2_scam = [scam_counter2[k] if k in scam_counter2.keys() else 0 for k in cate]
count_dict = {
    "category": cate, 
    "preroll_ad": preroll_ad_count, 
    "preroll_ad2": preroll_ad2_count,
    "preroll_ad_scam": preroll_ad_scam,
    "preroll_ad2_scam": preroll_ad2_scam,
}
df_count = pd.DataFrame(count_dict)
display(df_count)
total = sum(counter2.values())
print(f"Number of pairs: {total}")
print(f"Number of scam ads in preroll 1: {sum(preroll_ad_scam)}/{total} = {sum(preroll_ad_scam)/total * 100:.1f}%")
print(f"Number of scam ads in preroll 2: {sum(preroll_ad2_scam)}/{total} = {sum(preroll_ad2_scam)/total * 100:.1f}%")
# Out:
#                  category  preroll_ad  preroll_ad2  preroll_ad_scam
# 0                   Games          83          104                1  \
# 1       Software Services          79           56                3
# 2        Utility/Services          25           19                2
# 3             Food/Drinks          15            8                1
# 4           Entertainment          14           12                5
# 5              Home Goods          11            6                1
# 6               Financial           9           13                5
# 7         Health Products           9           21                2
# 8                  Beauty           9            3                1
# 9       Consumer Hardware           8            7                0
# 10               Clothing           8            7                1
# 11   Nonprofit University           7            3                0
# 12        Health Services           6            4                0
# 13               Donation           6            2                0
# 14  For-profit University           6            3                2
# 15      Special Interests           5            2                0
# 16     Business/Marketing           5           22                1
# 17                   News           3            2                0
# 18            Electronics           3            2                0
# 19                Fitness           2            5                0
# 20   Educational Services           2            8                0
# 21              Lifestyle           1            3                1
# 22     Traveling Services           1            3                0
#
#     preroll_ad2_scam
# 0                  1
# 1                  1
# 2                  3
# 3                  0
# 4                  1
# 5                  4
# 6                  9
# 7                 15
# 8                  0
# 9                  2
# 10                 0
# 11                 1
# 12                 1
# 13                 0
# 14                 2
# 15                 0
# 16                18
# 17                 0
# 18                 2
# 19                 4
# 20                 1
# 21                 3
# 22                 1
# Number of pairs: 317
# Number of scam ads in preroll 1: 26/317 = 8.2%
# Number of scam ads in preroll 2: 69/317 = 21.8%
