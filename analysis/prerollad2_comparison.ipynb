# %%
import json 
import csv
import pandas as pd
import os

# Go up one dir

if not os.path.exists("ads/"):
    os.chdir("..")

# %%
import warnings
warnings.filterwarnings("ignore")

run_ids = ["20230518_1957", "20230526_1750", "20230527_2230",
           "20230530_1949", "20230529_2213", "20230601_1751",
           "20230606_0332", "20230606_1947", "20230615_2208",
           "20230619_1605", "20230620_2248", "20230621_2131",
           "20230622_2327", "20230623_2257"]


        
def get_tagging(info, database):
    # info is a tuple (video_url, site)
    
    url, site = info
    url = url.replace(" ", "")
    site = site.replace(" ", "")
    
    url_db = database[database["preroll_ad_video_url"]==url]
    if len(url_db) != 0:
        return url_db.iloc[0]["tag"], url_db.iloc[0]["is_scam"]
    
    site_db = database[database["preroll_ad_site"]==site]
    if len(site_db) != 0:
        return site_db.iloc[0]["tag"], site_db.iloc[0]["is_scam"]
    
    return None, None


# build the database
def build_database():
    tag_header = ["preroll_ad_video_url", "preroll_ad_site", "preroll_ad_advertiser",
                  "preroll_ad_location", "id", "tag", "is_scam"]

    db = pd.read_excel("ads/preroll_ads_tagging.xlsx", sheet_name = run_ids)
    dfs = []

    for run_id in run_ids:
        df = db.get(run_id)
        df = df[df['preroll_ad_video_url'].notna()]
        df['run_id'] = run_id
        dfs.append(df)

    database = pd.concat(dfs, ignore_index=True)
    return database

# %%
database = build_database()
database
# Out:
#                              preroll_ad_video_url
# 0     https://www.youtube.com/watch?v=LCTqyxEUmHU  \
# 1     https://www.youtube.com/watch?v=DcD1tOMiIvk
# 2     https://www.youtube.com/watch?v=jR-gYFNLVxs
# 3     https://www.youtube.com/watch?v=PahO1czqaqM
# 4     https://www.youtube.com/watch?v=kuQIm72_H3o
# ...                                           ...
# 1975  https://www.youtube.com/watch?v=3sJeZOo7H8k
# 1976  https://www.youtube.com/watch?v=pk-4zHSsdg4
# 1977  https://www.youtube.com/watch?v=9JGuggkNMr8
# 1978  https://www.youtube.com/watch?v=1uXgHs7rxXQ
# 1979  https://www.youtube.com/watch?v=4PcD7F3JnX4
#
#                          preroll_ad_site    preroll_ad_advertiser
# 0                    parasitesnomore.com  PureHealth Research LLC  \
# 1     pacificrimathletics.com/online-reg    Pacific Rim Athletics
# 2                       click.doodly.com               Voomly LLC
# 3               go.masterclass-piano.com    Creators Secrets Inc.
# 4                     cf.spybriefing.com                      NaN
# ...                                  ...                      ...
# 1975             adaptivehealthtips.org                       NaN
# 1976  apimetrology.com/ladar/automation                       NaN
# 1977                       acrisure.com             Acrisure, LLC
# 1978          nexcess.net/hosting/plans            Liquid Web Inc
# 1979                        dataiku.com             Dataiku, Inc.
#
#      preroll_ad_location                   tag  is_scam
# 0          United States       Health Products        1  \
# 1          United States               Fitness        1
# 2          United States     Software Services        0
# 3          United States  Educational Services        1
# 4                    NaN               Fitness        1
# ...                  ...                   ...      ...
# 1975                 NaN       Health Products        1
# 1976                 NaN   Industrial Hardware        0
# 1977       United States             Financial        0
# 1978       United States     Software Services        0
# 1979       United States     Software Services        0
#
#                                           Notes         run_id  df_index
# 0                                           NaN  20230518_1957       NaN  \
# 1     athletic training, 10k for a short course  20230518_1957       NaN
# 2                   sketchy hidden subscription  20230518_1957       NaN
# 3                                           NaN  20230518_1957       NaN
# 4           self-defense training, very sketchy  20230518_1957       NaN
# ...                                         ...            ...       ...
# 1975                                        NaN  20230623_2257       NaN
# 1976                                        NaN  20230623_2257       NaN
# 1977                                        NaN  20230623_2257       NaN
# 1978                                        NaN  20230623_2257       NaN
# 1979                                        NaN  20230623_2257       NaN
#
#           id
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 1975  4946.0
# 1976  4962.0
# 1977  4977.0
# 1978  4977.0
# 1979  4993.0
#
# [1980 rows x 10 columns]

# %%
from collections import Counter


info = ["video_url",
          "preroll_ad_video_url", "preroll_ad_site","preroll_ad_info",
          "preroll_ad2_video_url", "preroll_ad2_site","preroll_ad2_info",]

header = ["id"] + info + ["tag", "is_scam", "tag2", "is_scam2"]
df_data = []
preroll_tags, preroll2_tags, preroll_scam, preroll2_scam = [], [], [], []

for id in run_ids:

    ad_json_file = open(f"ads/ads_{id}.json", "r", encoding="utf-8")

    for line in ad_json_file:
        json_data = json.loads(line)

        if json_data['preroll_ad_video_url'] and json_data['preroll_ad2_video_url']:
            if json_data['preroll_ad_video_url'] != json_data['video_url'] and json_data['preroll_ad2_video_url'] != json_data['video_url']:
                
                video_url, site = json_data["preroll_ad_video_url"], json_data["preroll_ad_site"]
                video_url2, site2 = json_data["preroll_ad2_video_url"], json_data["preroll_ad2_site"]
                tag, is_scam = get_tagging((video_url, site), database)
                tag2, is_scam2 = get_tagging((video_url2, site2), database)
                
                preroll_tags.append(tag)
                preroll2_tags.append(tag2)
                if is_scam:
                    preroll_scam.append(tag)
                if is_scam2:
                    preroll2_scam.append(tag2)
                
                data = [id] + [json_data[cate] for cate in info] + [tag, is_scam, tag2, is_scam2]
                df_data.append(data)
    
df = pd.DataFrame(df_data, columns=header)
df.to_excel("preroll_pairs.xlsx", index=False)
df
# Out:
#                 id                                    video_url
# 0    20230518_1957  https://www.youtube.com/watch?v=6v4SLn-_GeE  \
# 1    20230518_1957  https://www.youtube.com/watch?v=HC05gzknxAI
# 2    20230518_1957  https://www.youtube.com/watch?v=EY5uZrnAJ2Y
# 3    20230518_1957  https://www.youtube.com/watch?v=4r-4mqy4F7Y
# 4    20230518_1957  https://www.youtube.com/watch?v=e54vOGWJIqs
# ..             ...                                          ...
# 446  20230623_2257  https://www.youtube.com/watch?v=8wXLcuHC-T0
# 447  20230623_2257  https://www.youtube.com/watch?v=7T8Qe-nrc08
# 448  20230623_2257  https://www.youtube.com/watch?v=3nbvoPOFoGc
# 449  20230623_2257  https://www.youtube.com/watch?v=5es8ug01y0w
# 450  20230623_2257  https://www.youtube.com/watch?v=--qBtQhdxDk
#
#                             preroll_ad_video_url
# 0    https://www.youtube.com/watch?v=BuIz-f6uUcM  \
# 1    https://www.youtube.com/watch?v=3l7BbB4KDAs
# 2    https://www.youtube.com/watch?v=1B9v3GbE2G4
# 3    https://www.youtube.com/watch?v=kEMXZu2scKE
# 4    https://www.youtube.com/watch?v=aEIZBfWF_jA
# ..                                           ...
# 446  https://www.youtube.com/watch?v=rqBofHgTi1U
# 447  https://www.youtube.com/watch?v=K-DP6jxl_D4
# 448  https://www.youtube.com/watch?v=PuvPYuOR5X4
# 449  https://www.youtube.com/watch?v=TqMYtgJy7h4
# 450  https://www.youtube.com/watch?v=9JGuggkNMr8
#
#                           preroll_ad_site
# 0             subscribe.theepochtimes.com  \
# 1                          betterhelp.com
# 2                                temu.com
# 3                           grammarly.com
# 4                           grammarly.com
# ..                                    ...
# 446   resources.darrenhardy.com/planning
# 447  support.savethechildren.org/conf...
# 448             noblegoldinvestments.com
# 449                        getjobber.com
# 450                         acrisure.com
#
#                                        preroll_ad_info
# 0    [MARKETFUEL SUBSCRIPTION SERVICES, United States]  \
# 1                    [BetterHelp, Inc., United States]
# 2                                         [None, None]
# 3                     [Grammarly, Inc., United States]
# 4                     [Grammarly, Inc., United States]
# ..                                                 ...
# 446                  [Darren Hardy LLC, United States]
# 447  [Save the Children Federation Inc, United States]
# 448                                       [None, None]
# 449                          [Octopusapp Inc., Canada]
# 450                     [Acrisure, LLC, United States]
#
#                            preroll_ad2_video_url
# 0    https://www.youtube.com/watch?v=T8fGIon1JZM  \
# 1    https://www.youtube.com/watch?v=c0ljp5YB1OE
# 2    https://www.youtube.com/watch?v=akLmxtIAoC4
# 3    https://www.youtube.com/watch?v=0PoMVDor5tY
# 4    https://www.youtube.com/watch?v=MopERx1yXvQ
# ..                                           ...
# 446  https://www.youtube.com/watch?v=k5b2t6kyyUg
# 447  https://www.youtube.com/watch?v=4I_VZbDFnR0
# 448  https://www.youtube.com/watch?v=HAj95SNBPV8
# 449  https://www.youtube.com/watch?v=DzUD5sg0muw
# 450  https://www.youtube.com/watch?v=1uXgHs7rxXQ
#
#                   preroll_ad2_site                         preroll_ad2_info
# 0          smartinvestorsdaily.com  [Powderday Digital, LLC, United States]  \
# 1                wellness-hub.life                             [None, None]
# 2                  livingproof.com       [Living Proof inc., United States]
# 3                wellness-hub.life              [Kuyami Inc, United States]
# 4    go.overwolf.com/free-download                   [Overwolf LTD, Israel]
# ..                             ...                                      ...
# 446               totalbattle.com            [SCOREWARRIOR LIMITED, Cyprus]
# 447     specialtycoaching.academy                              [None, None]
# 448                  acrisure.com            [Acrisure, LLC, United States]
# 449              expertschool.com                              [None, None]
# 450     nexcess.net/hosting/plans           [Liquid Web Inc, United States]
#
#                    tag  is_scam                tag2  is_scam2
# 0                 News        0           Financial         1
# 1      Health Services        0     Health Products         1
# 2       Major Retailer        0              Beauty         0
# 3    Software Services        0     Health Products         1
# 4    Software Services        0               Games         0
# ..                 ...      ...                 ...       ...
# 446          Lifestyle        1               Games         0
# 447           Donation        0  Business/Marketing         1
# 448          Financial        0           Financial         0
# 449  Software Services        0  Business/Marketing         1
# 450          Financial        0   Software Services         0
#
# [451 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

counter = Counter(preroll_tags)
counter2 = Counter(preroll2_tags)
scam_counter = Counter(preroll_scam)
scam_counter2 = Counter(preroll2_scam)


cate = list(counter.keys()) + list(counter2.keys())
cate = list(set(cate))

preroll_ad_count = [counter[i] for i in cate]
preroll_ad2_count = [counter2[i] for i in cate]
preroll_ad_scam = [scam_counter[k] if k in scam_counter.keys() else 0 for k in cate]
preroll_ad2_scam = [scam_counter2[k] if k in scam_counter2.keys() else 0 for k in cate]
count_dict = {
    "category": cate, 
    "preroll_ad": preroll_ad_count, 
    "preroll_ad2": preroll_ad2_count,
    "preroll_ad_scam": preroll_ad_scam,
    "preroll_ad2_scam": preroll_ad2_scam,
}
df_count = pd.DataFrame(count_dict)
df_count.sort_values("preroll_ad", inplace=True, ascending=False, ignore_index=True)
display(df_count)
total = sum(counter2.values())
print(f"Number of pairs: {total}")
print(f"Number of scam ads in preroll 1: {len(preroll_scam)}/{total} = {len(preroll_scam)/total * 100:.1f}%")
print(f"Number of scam ads in preroll 2: {len(preroll2_scam)}/{total} = {len(preroll2_scam)/total * 100:.1f}%")
# Out:
#                  category  preroll_ad  preroll_ad2  preroll_ad_scam
# 0       Software Services         145           97                0  \
# 1                   Games          96          116                0
# 2           Entertainment          21           14                0
# 3        Utility/Services          19           24                2
# 4               Financial          19           25                5
# 5             Food/Drinks          16            8                0
# 6          Major Retailer          15            3                0
# 7                Clothing          14            9                0
# 8         Health Products          11           27                1
# 9              Home Goods          11           13                0
# 10                 Beauty          10            3                0
# 11      Consumer Hardware           9            8                0
# 12  For-profit University           9            5                2
# 13               Donation           9            3                0
# 14   Nonprofit University           8            4                0
# 15        Health Services           7            9                0
# 16   Educational Services           6           19                0
# 17     Business/Marketing           5           38                1
# 18                Fitness           5            3                0
# 19      Special Interests           5            4                0
# 20                   News           3            4                0
# 21            Electronics           3            5                0
# 22     Traveling Services           3            3                0
# 23              Lifestyle           2            5                2
# 24    Industrial Hardware           0            2                0
#
#     preroll_ad2_scam
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                 20
# 5                  0
# 6                  0
# 7                  0
# 8                 18
# 9                  2
# 10                 0
# 11                 3
# 12                 1
# 13                 0
# 14                 0
# 15                 1
# 16                 1
# 17                34
# 18                 2
# 19                 0
# 20                 0
# 21                 4
# 22                 0
# 23                 5
# 24                 0
# Number of pairs: 451
# Number of scam ads in preroll 1: 13/451 = 2.9%
# Number of scam ads in preroll 2: 91/451 = 20.2%
