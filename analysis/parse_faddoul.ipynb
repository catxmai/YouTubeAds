# %%
import json 
import csv
import pandas as pd
import os

# Go up one dir

if not os.path.exists("ads/"):
    os.chdir("..")

# %%
faddoul = open("faddoul_conspiracy.json", 'r', encoding="utf-8")
df = pd.read_json(faddoul)
df['videoid'] = df.index
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                   title
# 0                How to Destroy the Climate Change Hoax  \
# 1      PROPHETIC RUMORS THAT ARE NOT TRUE | EPISODE 984
# 2                      The Royal Scandal Of The Century
# 3     QTR #139 - Whitney Webb Goes Deep: Blowing Ope...
# 4     Cup of Gethsemane as You've Never Seen It Before!
# ...                                                 ...
# 6747  1-Second Puzzle During Earthfiles YouTube Chan...
# 6748  2 Baruch: To YOU, Child of ISRAEL / Yashar'el ...
# 6749  2 Esdras: SIGNS of the Times and Judgement - P...
# 6750  2 Baruch: The Vision of the Bright and Black W...
# 6751            Geography​ Now! Ireland (BEST REACTION)
#
#                 channel_title  reco_count  view_count  comment_count
# 0          TFP Student Action           7    218627.0         4336.0  \
# 1                 Perry Stone          47     51329.0          262.0
# 2               Shaun Attwood          36    184487.0         3080.0
# ...

# %%
df.to_csv("faddoul_conspiracy.csv")
